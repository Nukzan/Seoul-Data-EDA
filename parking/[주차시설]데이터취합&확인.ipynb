# %% [markdown]
# # 모듈 import

# %%
import os
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.style as style
style.use('fivethirtyeight')

# %%
# 한글 폰트 설정

from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/999.fonts/NanumGothic.ttf").get_name()
rc('font', family=font_name)

# %% [markdown]
# # 데이터 불러오기

# %%
# 텍스트 파일 변환

# 주차장 확보율 통계 2011-19
car_prk_rt = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2011-19_서울시 주차장 확보율 통계.txt', sep = "\t", engine= 'python')


## 주차장 통계 2010-19
car_prk_2010 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2010_서울시 주차장 (구별) 통계.txt', sep = "\t", engine= 'python')
car_prk_2011 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2011_서울시 주차장 (구별) 통계.txt', sep = "\t", engine= 'python')
car_prk_2012 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2012_서울시 주차장 (구별) 통계.txt', sep = "\t", engine= 'python')
car_prk_2013 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2013_서울시 주차장 (구별) 통계.txt', sep = "\t", engine= 'python')
car_prk_2014 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2014_서울시 주차장 (구별) 통계.txt', sep = "\t", engine= 'python')
car_prk_2015 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2015_서울시 주차장 (구별) 통계.txt', sep = "\t", engine= 'python')
car_prk_2016 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2016_서울시 주차장 (구별) 통계.txt', sep = "\t", engine= 'python')
car_prk_2017 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2017_서울시 주차장 (구별) 통계.txt', sep = "\t", engine= 'python')
car_prk_2018 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2018_서울시 주차장 (구별) 통계.txt', sep = "\t", engine= 'python')
car_prk_2019 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2019_서울시 주차장 (구별) 통계.txt', sep = "\t", engine= 'python')


## 자동차 등록 통계 2010-20
car_erl_2010 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2010_서울시 자동차등록 (월별구별) 통계.txt', sep = "\t", engine= 'python')
car_erl_2011 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2011_서울시 자동차등록 (월별구별) 통계.txt', sep = "\t", engine= 'python')
car_erl_2012 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2012_서울시 자동차등록 (월별구별) 통계.txt', sep = "\t", engine= 'python')
car_erl_2013 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2013_서울시 자동차등록 (월별구별) 통계.txt', sep = "\t", engine= 'python')
car_erl_2014 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2014_서울시 자동차등록 (월별구별) 통계.txt', sep = "\t", engine= 'python')
car_erl_2015 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2015_서울시 자동차등록 (월별구별) 통계.txt', sep = "\t", engine= 'python')
car_erl_2016 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2016_서울시 자동차등록 (월별구별) 통계.txt', sep = "\t", engine= 'python')
car_erl_2017 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2017_서울시 자동차등록 (월별구별) 통계.txt', sep = "\t", engine= 'python')
car_erl_2018 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2018_서울시 자동차등록 (월별구별) 통계.txt', sep = "\t", engine= 'python')
car_erl_2019 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2019_서울시 자동차등록 (월별구별) 통계.txt', sep = "\t", engine= 'python')
car_erl_2020 = pd.read_csv('./drive/MyDrive/dataanalysis_real/⚡SunDerGirls🐥/서울시_1인가구_data/3.주차시설/2020_서울시 자동차등록 (월별구별) 통계.txt', sep = "\t", engine= 'python')

# %% [markdown]
# ## 데이터 취합
#
# - 년도별로 흩어진 데이터 취합 (보행만족도 조사 2010~2019)

# %%
# 주차장 통계 년도데이터 취합

car_prk = pd.concat([car_prk_2010,car_prk_2011,car_prk_2012,car_prk_2013,car_prk_2014
                     ,car_prk_2015,car_prk_2016,car_prk_2017,car_prk_2018,car_prk_2019])

car_prk
# Out:
#       기간  자치구       합계       합계.1  ... 건축물부설.6    건축물부설.7 노상.8 노상.9
# 0     기간  자치구        계          계  ...   일반건축물      일반건축물  NaN  NaN
# 1     기간  자치구        계          계  ...   일반건축물      일반건축물  NaN  NaN
# 2     기간  자치구       개소         면수  ...      개소         면수  NaN  NaN
# 3   2010  서울시  299,166  3,404,346  ...  86,958  1,184,792  NaN  NaN
# 4   2010  종로구    5,452     71,720  ...   2,199     38,980  NaN  NaN
# ..   ...  ...      ...        ...  ...     ...        ...  ...  ...
# 23  2019  관악구   20,442    152,131  ...   5,049     41,186  NaN  NaN
# 24  2019  서초구   12,390    261,294  ...   5,252    114,691  NaN  NaN
# 25  2019  강남구   19,829    395,951  ...   9,498    206,663  NaN  NaN
# 26  2019  송파구   22,650    351,025  ...   5,708    144,639  NaN  NaN
# 27  2019  강동구   19,994    193,311  ...   8,733     68,323  NaN  NaN
#
# [286 rows x 34 columns]

# %%
# 자동차 등록 년도데이터 취합

car_erl = pd.concat([car_erl_2010,car_erl_2011,car_erl_2012,car_erl_2013,car_erl_2014,
                     car_erl_2015,car_erl_2016,car_erl_2017,car_erl_2018,car_erl_2019,car_erl_2020])

car_erl
# Out:
#       기간  자치구         합계    합계.1  ...  특수차.3      이륜차  이륜차.1    이륜차.2
# 0     기간  자치구          계      관용  ...    영업용        계     관용      자가용
# 1   2010  서울시  2,981,400  10,499  ...  2,504  410,615  3,610  407,005
# 2   2010  종로구     49,669   1,605  ...     18   12,871    286   12,585
# 3   2010   중구     62,495     929  ...     82   13,692    124   13,568
# 4   2010  용산구     75,579     467  ...     48   15,439    130   15,309
# ..   ...  ...        ...     ...  ...    ...      ...    ...      ...
# 23  2020  서초구    181,053     535  ...    156   12,518    294   12,224
# 24  2020  강남구    236,216     393  ...    164   18,230    320   17,910
# 25  2020  송파구    245,833     392  ...    279   20,813    199   20,614
# 26  2020  강동구    149,866     291  ...    228   17,170    144   17,026
# 27  2020   기타          -       -  ...      -       12      -       12
#
# [306 rows x 25 columns]

# %%
# 년도별/자치구별 데이터만 추출

c2010 = crs_env_2010.loc[crs_env_2010[crs_env_2010['분류']=='종로구'].index.tolist()[0]:]
c2011 = crs_env_2011.loc[crs_env_2011[crs_env_2011['분류']=='종로구'].index.tolist()[0]:]
c2012 = crs_env_2012.loc[crs_env_2012[crs_env_2012['분류']=='종로구'].index.tolist()[0]:]
c2013 = crs_env_2013.loc[crs_env_2013[crs_env_2013['분류']=='종로구'].index.tolist()[0]:]
c2014 = crs_env_2014.loc[crs_env_2014[crs_env_2014['분류']=='종로구'].index.tolist()[0]:]
c2015 = crs_env_2015.loc[crs_env_2015[crs_env_2015['분류']=='종로구'].index.tolist()[0]:]
c2016 = crs_env_2016.loc[crs_env_2016[crs_env_2016['분류']=='종로구'].index.tolist()[0]:]
c2017 = crs_env_2017.loc[crs_env_2017[crs_env_2017['분류']=='종로구'].index.tolist()[0]:]
c2018 = crs_env_2018.loc[crs_env_2018[crs_env_2018['분류']=='종로구'].index.tolist()[0]:]
c2019 = crs_env_2019.loc[crs_env_2019[crs_env_2019['분류']=='종로구'].index.tolist()[0]:]

# %%
# 보행환경 만족도 연별/자치구별 데이터 취합
crs_env = pd.concat([c2010, c2011, c2012, c2013, c2014,
                     c2015, c2016, c2017, c2018, c2019])

# %%
crs_env.sort_values(by=['기간','분류'])
# Out:
#       기간  대분류   분류    종합  주거지역 서울도심(시내) 밤늦은 야간보행
# 51  2010  강남구  강남구  6.02  6.41     5.62      NaN
# 53  2010  강동구  강동구  6.38  6.41     6.35      NaN
# 37  2010  강북구  강북구  5.64  5.77     5.52      NaN
# 44  2010  강서구  강서구  5.49  5.73     5.24      NaN
# 49  2010  관악구  관악구  6.13  6.23     6.03      NaN
# ..   ...  ...  ...   ...   ...      ...      ...
# 29  2019  용산구  용산구  6.21  6.39     6.42     5.82
# 38  2019  은평구  은평구   5.8  6.22     6.18        5
# 27  2019  종로구  종로구  5.91  6.49     6.16     5.09
# 28  2019   중구   중구  6.13  6.42     6.44     5.51
# 33  2019  중랑구  중랑구  6.11   6.4     6.45     5.48
#
# [250 rows x 7 columns]

# %% [markdown]
# # 데이터 분석

# %% [markdown]
# ## 주차장 확보율 2011-19
#
# - dataframe : car_prk_rt
# - columns : '기간', '자치구', '자동차등록대수', '주차면수', '주차장확보율'
#
# - 볼만한 내용
#   - 년도별 주차장 확보율 (전체/지역)

# %%
car_prk_rt.columns
# Out:
# Index(['기간', '자치구', '자동차등록대수', '주차면수', '주차장확보율'], dtype='object')

# %%
car_prk_rt
# Out:
#        기간  자치구    자동차등록대수       주차면수  주차장확보율
# 0    2011   총계  2,977,599  3,595,750   120.8
# 1    2011  종로구     52,047     89,180   171.3
# 2    2011   중구     61,378    101,128   164.8
# 3    2011  용산구     76,714    104,741   136.5
# 4    2011  성동구     87,217    105,505   121.0
# ..    ...  ...        ...        ...     ...
# 229  2019  관악구    120,050    152,131   126.7
# 230  2019  서초구    181,182    261,294   144.2
# 231  2019  강남구    235,415    395,951   168.2
# 232  2019  송파구    240,559    351,025   145.9
# 233  2019  강동구    139,549    193,311   138.5
#
# [234 rows x 5 columns]

# %% [markdown]
# 총 234개 레코드

# %%
car_prk_rt.describe()
# Out:
#                 기간      주차장확보율
# count   234.000000  234.000000
# mean   2015.000000  128.677778
# std       2.587524   22.227283
# min    2011.000000   77.200000
# 25%    2013.000000  114.350000
# 50%    2015.000000  124.000000
# 75%    2017.000000  137.550000
# max    2019.000000  208.900000

# %% [markdown]
# 주차장 확보율 평균값 128.67 / 표준편차 22.22 / 최소값 77.20 / 최대값 208.90

# %%
car_prk_rt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   기간       234 non-null    int64
#  1   자치구      234 non-null    object
#  2   자동차등록대수  234 non-null    object
#  3   주차면수     234 non-null    object
#  4   주차장확보율   234 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 9.3+ KB

# %% [markdown]
# - null 값 없음
# - 기간 int, 주차장확보율 float

# %%
# 년도별 주차장확보율 추이

car_total = car_prk_rt[car_prk_rt['자치구']=='총계']

plt.figure(figsize=(13,5))
plt.title('2011-2019 서울시 주차장확보율 추이')
plt.xticks(rotation=45, size=10)
plt.plot(car_total['기간'], car_total['주차장확보율'])
plt.show()
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50872 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# ## 교통사고 통계 2010-19
#
# - dataframe : crs_acdt
# - columns : '기간', '지역', '발생건수', '자동차 1만대당 발생건수', '사망자수', '인구 10만명당 사망자수', '부상자수', '인구 10만명당 부상자수'
#
# - 볼만한 데이터 : 인구10만당사망자수, 자동차1만대당발생건수 연도별 증감, 전체 발생건수 및 사망자수 대비 각 자치구의 비중

# %%
crs_acdt
# Out:
#        기간   지역    발생건수  ...  인구 10만명당 사망자수    부상자수  인구 10만명당 부상자수
# 0    2010   합계  41,662  ...            4.1  59,718          564.7
# 1    2010  종로구   1,436  ...           10.6   2,009        1,120.1
# 2    2010   중구   1,540  ...            5.0   2,152        1,524.1
# 3    2010  용산구   1,245  ...            5.8   1,738          675.9
# 4    2010  성동구   1,097  ...            4.7   1,528          482.2
# ..    ...  ...     ...  ...            ...     ...            ...
# 255  2019  관악구   1,363  ...            1.9   1,755          339.2
# 256  2019  서초구   2,418  ...            3.2   3,530          811.3
# 257  2019  강남구   3,722  ...            2.5   5,182          941.8
# 258  2019  송파구   2,892  ...            1.9   4,003          586.3
# 259  2019  강동구   1,414  ...            2.5   1,910          433.7
#
# [260 rows x 8 columns]

# %%
crs_acdt.columns
# Out:
# Index(['기간', '지역', '발생건수', '자동차 1만대당 발생건수', '사망자수', '인구 10만명당 사망자수', '부상자수',
#        '인구 10만명당 부상자수'],
#       dtype='object')

# %%
crs_acdt.describe()
# Out:
#                 기간  자동차 1만대당 발생건수        사망자수  인구 10만명당 사망자수
# count   260.000000     260.000000  260.000000     260.000000
# mean   2014.500000     119.026538   28.361538       3.816538
# std       2.877821      31.422986   69.339966       1.674195
# min    2010.000000      67.400000    3.000000       0.800000
# 25%    2012.000000      94.100000   11.000000       2.600000
# 50%    2014.500000     113.200000   14.000000       3.600000
# 75%    2017.000000     134.125000   19.000000       4.500000
# max    2019.000000     229.600000  435.000000      12.700000

# %% [markdown]
# ## 보행환경 만족도 통계 2010-19
#
# - dataframe : crs_env
# - columns : '기간', '대분류', '분류', '종합', '주거지역', '서울도심(시내)', '밤늦은 야간보행'
#
# - 볼만한 데이터 : 지역별 종합점수 년도별증감 비교

# %%
crs_env.columns
# Out:
# Index(['기간', '대분류', '분류', '종합', '주거지역', '서울도심(시내)', '밤늦은 야간보행'], dtype='object')

# %%
crs_env
# Out:
#       기간  대분류   분류    종합  주거지역 서울도심(시내) 밤늦은 야간보행
# 29  2010  종로구  종로구  5.77  5.81     5.73      NaN
# 30  2010   중구   중구  6.06  6.26     5.86      NaN
# 31  2010  용산구  용산구  5.69  5.53     5.85      NaN
# 32  2010  성동구  성동구  6.25  6.08     6.42      NaN
# 33  2010  광진구  광진구  5.41  5.54     5.28      NaN
# ..   ...  ...  ...   ...   ...      ...      ...
# 47  2019  관악구  관악구     6  6.28     6.39     5.32
# 48  2019  서초구  서초구  6.21   6.7     6.36     5.57
# 49  2019  강남구  강남구  6.19  6.54     6.45     5.57
# 50  2019  송파구  송파구  6.43  6.74     6.62     5.94
# 51  2019  강동구  강동구  5.72  6.06     6.03     5.06
#
# [250 rows x 7 columns]

# %%
crs_env.describe()
# Out:
#                 기간
# count   250.000000
# mean   2014.500000
# std       2.878043
# min    2010.000000
# 25%    2012.000000
# 50%    2014.500000
# 75%    2017.000000
# max    2019.000000
